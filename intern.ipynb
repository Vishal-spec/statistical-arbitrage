# %%
import pandas as pd
import numpy as np
data=pd.read_csv("intern.csv")

# %%
data.head()
# Out:
#        SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
# 0   20MICRONS     EQ     37.80     37.80     36.15     36.85     37.40
# 1  3IINFOTECH     EQ      4.10      4.85      4.00      4.55      4.65
# 2     3MINDIA     EQ  13425.15  13469.55  12920.00  13266.70  13300.00
# 3     63MOONS     EQ     61.00     61.90     60.35     61.00     61.10
# 4     8KMILES     EQ    546.10    548.00    535.00    537.45    535.20
#
#    PREVCLOSE  TOTTRDQTY    TOTTRDVAL   TIMESTAMP  TOTALTRADES          ISIN
# 0      37.05      27130    994657.90  2017-06-28          202  INE144J01027
# 1       4.05   20157058  92148517.65  2017-06-28         7353  INE748C01020
# 2   13460.55       2290  30304923.35  2017-06-28          748  INE470A01017
# 3      60.65      27701   1689421.00  2017-06-28          437  INE111B01023
# 4     547.45      79722  43208620.05  2017-06-28         1866  INE650K01021

# %%
data.shape
# Out:
# (846404, 13)

# %%
data["TIMESTAMP"]
num=0
for i in data["TIMESTAMP"]:
    if i[3]=="6":
        print(i)
        print(num)
    num+=1
# Out:
# 2016-04-21
# 435391
# 2016-04-21
# 435392
# 2016-04-21
# 435393
# 2016-04-21
# 435394
# 2016-04-21
# 435395
# 2016-04-21
# 435396
# 2016-04-21
# 435397
# 2016-04-21
# 435398
# 2016-04-21
# 435399
# 2016-04-21
# 435400
# 2016-04-21
# 435401
# 2016-04-21
# 435402
# 2016-04-21
# 435403
# 2016-04-21
# 435404
# 2016-04-21
# 435405
# 2016-04-21
# 435406
# 2016-04-21
# 435407
# 2016-04-21
# 435408
# 2016-04-21
# 435409
# 2016-04-21
# 435410
# 2016-04-21
# 435411
# 2016-04-21
# 435412
# 2016-04-21
# 435413
# 2016-04-21
# 435414
# 2016-04-21
# 435415
# 2016-04-21
# 435416
# 2016-04-21
# 435417
# 2016-04-21
# 435418
# 2016-04-21
# 435419
# 2016-04-21
# 435420
# 2016-04-21
# 435421
# 2016-04-21
# 435422
# 2016-04-21
# 435423
# 2016-04-21
# 435424
# 2016-04-21
# 435425
# 2016-04-21
# 435426
# 2016-04-21
# 435427
# 2016-04-21
# 435428
# 2016-04-21
# 435429
# 2016-04-21
# 435430
# 2016-04-21
# 435431
# 2016-04-21
# 435432
# 2016-04-21
# 435433
# 2016-04-21
# 435434
# 2016-04-21
# 435435
# ...

# %%
splitter=data
train=data
train=train[435391:844554][:]
splitter.drop(splitter.index[range(435391,844554)],inplace=True)
test=splitter
data.shape
# Out:
# (437241, 13)

# %%
test.head()
# Out:
#        SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
# 0   20MICRONS     EQ     37.80     37.80     36.15     36.85     37.40
# 1  3IINFOTECH     EQ      4.10      4.85      4.00      4.55      4.65
# 2     3MINDIA     EQ  13425.15  13469.55  12920.00  13266.70  13300.00
# 3     63MOONS     EQ     61.00     61.90     60.35     61.00     61.10
# 4     8KMILES     EQ    546.10    548.00    535.00    537.45    535.20
#
#    PREVCLOSE  TOTTRDQTY    TOTTRDVAL   TIMESTAMP  TOTALTRADES          ISIN
# 0      37.05      27130    994657.90  2017-06-28          202  INE144J01027
# 1       4.05   20157058  92148517.65  2017-06-28         7353  INE748C01020
# 2   13460.55       2290  30304923.35  2017-06-28          748  INE470A01017
# 3      60.65      27701   1689421.00  2017-06-28          437  INE111B01023
# 4     547.45      79722  43208620.05  2017-06-28         1866  INE650K01021

# %%
test.shape
# Out:
# (437241, 13)

# %%
print(train)
# Out:
#             SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
# 435391   20MICRONS     EQ     33.90     35.00     32.25     33.00     33.30
# 435392  3IINFOTECH     EQ      4.40      4.45      4.30      4.30      4.30
# 435393     3MINDIA     EQ  13939.70  14200.00  13324.00  13424.10  13400.05
# 435394     8KMILES     EQ   2018.95   2029.10   1956.20   1973.40   1970.25
# 435395    A2ZINFRA     EQ     26.40     26.80     25.80     25.90     25.80
# ...            ...    ...       ...       ...       ...       ...       ...
# 844549   ZODJRDMKJ     EQ     41.40     41.40     36.80     37.90     37.95
# 844550       ZUARI     EQ    188.35    189.80    185.05    185.25    185.15
# 844551   ZUARIGLOB     EQ     95.30     97.40     94.25     94.50     94.30
# 844552   ZYDUSWELL     EQ    900.00    910.00    886.05    888.40    892.00
# 844553       ZYLOG     EQ      2.90      3.05      2.90      3.05      3.00
#
# ...

# %%
train[100]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 100
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-ce26562f0d53> in <module>
# ----> 1 train[100]
#
# ...

# %%
train.head()
# Out:
#                 SYMBOL SERIES      OPEN      HIGH       LOW    CLOSE  \
# Date
# 2016-04-21   20MICRONS     EQ     33.90     35.00     32.25     33.0
# 2016-04-21  3IINFOTECH     EQ      4.40      4.45      4.30      4.3
# 2016-04-21     3MINDIA     EQ  13939.70  14200.00  13324.00  13424.1
# 2016-04-21     8KMILES     EQ   2018.95   2029.10   1956.20   1973.4
# 2016-04-21    A2ZINFRA     EQ     26.40     26.80     25.80     25.9
#
#                 LAST  PREVCLOSE  TOTTRDQTY    TOTTRDVAL   TIMESTAMP  \
# Date
# 2016-04-21     33.30      33.75      48174   1593805.60  2016-04-21
# 2016-04-21      4.30       4.35     684070   2991352.25  2016-04-21
# 2016-04-21  13400.05   14080.50       1464  20233135.70  2016-04-21
# 2016-04-21   1970.25    2000.85      28967  57987253.05  2016-04-21
# 2016-04-21     25.80      26.30      91366   2388936.45  2016-04-21
#
#             TOTALTRADES          ISIN       Date
# Date
# 2016-04-21          253  INE144J01027 2016-04-21
# ...

# %%
train.shape
# Out:
# (409163, 14)

# %%
train["TIMESTAMP"]
# Out:
# Date
# 2016-04-21    2016-04-21
# 2016-04-21    2016-04-21
# 2016-04-21    2016-04-21
# 2016-04-21    2016-04-21
# 2016-04-21    2016-04-21
#                  ...
# 2016-09-23    2016-09-23
# 2016-09-23    2016-09-23
# 2016-09-23    2016-09-23
# 2016-09-23    2016-09-23
# 2016-09-23    2016-09-23
# Name: TIMESTAMP, Length: 409163, dtype: object

# %%
test["TIMESTAMP"]
# Out:
# Date
# 2017-06-28    2017-06-28
# 2017-06-28    2017-06-28
# 2017-06-28    2017-06-28
# 2017-06-28    2017-06-28
# 2017-06-28    2017-06-28
#                  ...
# 2017-12-29    2017-12-29
# 2017-12-29    2017-12-29
# 2017-12-29    2017-12-29
# 2017-12-29    2017-12-29
# 2017-12-29    2017-12-29
# Name: TIMESTAMP, Length: 437241, dtype: object

# %%
train=train.reset_index(drop=True)

# %%
test=test.reset_index(drop=True)
test.head()
# Out:
#        SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
# 0   20MICRONS     EQ     37.80     37.80     36.15     36.85     37.40
# 1  3IINFOTECH     EQ      4.10      4.85      4.00      4.55      4.65
# 2     3MINDIA     EQ  13425.15  13469.55  12920.00  13266.70  13300.00
# 3     63MOONS     EQ     61.00     61.90     60.35     61.00     61.10
# 4     8KMILES     EQ    546.10    548.00    535.00    537.45    535.20
#
#    PREVCLOSE  TOTTRDQTY    TOTTRDVAL   TIMESTAMP  TOTALTRADES          ISIN  \
# 0      37.05      27130    994657.90  2017-06-28          202  INE144J01027
# 1       4.05   20157058  92148517.65  2017-06-28         7353  INE748C01020
# 2   13460.55       2290  30304923.35  2017-06-28          748  INE470A01017
# 3      60.65      27701   1689421.00  2017-06-28          437  INE111B01023
# 4     547.45      79722  43208620.05  2017-06-28         1866  INE650K01021
#
#         Date
# 0 2017-06-28
# 1 2017-06-28
# 2 2017-06-28
# 3 2017-06-28
# ...

# %%
train.head()
# Out:
#        SYMBOL SERIES      OPEN      HIGH       LOW    CLOSE      LAST  \
# 0   20MICRONS     EQ     33.90     35.00     32.25     33.0     33.30
# 1  3IINFOTECH     EQ      4.40      4.45      4.30      4.3      4.30
# 2     3MINDIA     EQ  13939.70  14200.00  13324.00  13424.1  13400.05
# 3     8KMILES     EQ   2018.95   2029.10   1956.20   1973.4   1970.25
# 4    A2ZINFRA     EQ     26.40     26.80     25.80     25.9     25.80
#
#    PREVCLOSE  TOTTRDQTY    TOTTRDVAL   TIMESTAMP  TOTALTRADES          ISIN  \
# 0      33.75      48174   1593805.60  2016-04-21          253  INE144J01027
# 1       4.35     684070   2991352.25  2016-04-21          360  INE748C01020
# 2   14080.50       1464  20233135.70  2016-04-21          722  INE470A01017
# 3    2000.85      28967  57987253.05  2016-04-21         3264  INE650K01013
# 4      26.30      91366   2388936.45  2016-04-21          576  INE619I01012
#
#         Date
# 0 2016-04-21
# 1 2016-04-21
# 2 2016-04-21
# 3 2016-04-21
# 4 2016-04-21

# %%
Y_train=train["CLOSE"]
Y_train.T
Y_test=test["CLOSE"]
Y_test.T
# Out:
# 0            36.85
# 1             4.55
# 2         13266.70
# 3            61.00
# 4           537.45
#             ...
# 437236      217.00
# 437237      550.80
# 437238      253.25
# 437239     1043.20
# 437240        4.65
# Name: CLOSE, Length: 437241, dtype: float64

# %%
from datetime import datetime
train["Date"]=pd.to_datetime(train.TIMESTAMP,format="%Y-%m-%d")
train.index=train["Date"]
train.head()
# Out:
#                 SYMBOL SERIES      OPEN      HIGH       LOW    CLOSE  \
# Date
# 2016-04-21   20MICRONS     EQ     33.90     35.00     32.25     33.0
# 2016-04-21  3IINFOTECH     EQ      4.40      4.45      4.30      4.3
# 2016-04-21     3MINDIA     EQ  13939.70  14200.00  13324.00  13424.1
# 2016-04-21     8KMILES     EQ   2018.95   2029.10   1956.20   1973.4
# 2016-04-21    A2ZINFRA     EQ     26.40     26.80     25.80     25.9
#
#                 LAST  PREVCLOSE  TOTTRDQTY    TOTTRDVAL   TIMESTAMP  \
# Date
# 2016-04-21     33.30      33.75      48174   1593805.60  2016-04-21
# 2016-04-21      4.30       4.35     684070   2991352.25  2016-04-21
# 2016-04-21  13400.05   14080.50       1464  20233135.70  2016-04-21
# 2016-04-21   1970.25    2000.85      28967  57987253.05  2016-04-21
# 2016-04-21     25.80      26.30      91366   2388936.45  2016-04-21
#
#             TOTALTRADES          ISIN       Date
# Date
# 2016-04-21          253  INE144J01027 2016-04-21
# ...

# %%
test["Date"]=pd.to_datetime(test.TIMESTAMP,format="%Y-%m-%d")
test.index=test["Date"]
test.head()
# Out:
#                 SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE  \
# Date
# 2017-06-28   20MICRONS     EQ     37.80     37.80     36.15     36.85
# 2017-06-28  3IINFOTECH     EQ      4.10      4.85      4.00      4.55
# 2017-06-28     3MINDIA     EQ  13425.15  13469.55  12920.00  13266.70
# 2017-06-28     63MOONS     EQ     61.00     61.90     60.35     61.00
# 2017-06-28     8KMILES     EQ    546.10    548.00    535.00    537.45
#
#                 LAST  PREVCLOSE  TOTTRDQTY    TOTTRDVAL   TIMESTAMP  \
# Date
# 2017-06-28     37.40      37.05      27130    994657.90  2017-06-28
# 2017-06-28      4.65       4.05   20157058  92148517.65  2017-06-28
# 2017-06-28  13300.00   13460.55       2290  30304923.35  2017-06-28
# 2017-06-28     61.10      60.65      27701   1689421.00  2017-06-28
# 2017-06-28    535.20     547.45      79722  43208620.05  2017-06-28
#
#             TOTALTRADES          ISIN       Date
# Date
# 2017-06-28          202  INE144J01027 2017-06-28
# ...

# %%
Y_train.index=train["Date"]

# %%
Y_train.head()
# Out:
# Date
# 2016-04-21       33.0
# 2016-04-21        4.3
# 2016-04-21    13424.1
# 2016-04-21     1973.4
# 2016-04-21       25.9
# Name: CLOSE, dtype: float64

# %%
Y_test.index=test["Date"]

# %%
Y_train.head()
# Out:
# Date
# 2016-04-21       33.0
# 2016-04-21        4.3
# 2016-04-21    13424.1
# 2016-04-21     1973.4
# 2016-04-21       25.9
# Name: CLOSE, dtype: float64

# %%
X_train=train
X_test=test
X_train=X_train.iloc[:,[2,3,4,8,9,11]]

# %%
X_test=X_test.iloc[:,[2,3,4,8,9,11]]

# %%
X_test=X_test[0:X_test.shape[0]][:]
Y_test=Y_test[0:Y_test.shape[0]][:]

# %%
X_train=X_train[0:X_train.shape[0]][:]
Y_train=Y_train[0:Y_train.shape[0]][:]

# %%
from sklearn.linear_model import TheilSenRegressor,LinearRegression,RANSACRegressor
clf=TheilSenRegressor()
clf.fit(X_train,Y_train)

# %%
X_train.head()
# Out:
#                 OPEN      HIGH       LOW  TOTTRDQTY    TOTTRDVAL  TOTALTRADES
# Date
# 2016-04-21     33.90     35.00     32.25      48174   1593805.60          253
# 2016-04-21      4.40      4.45      4.30     684070   2991352.25          360
# 2016-04-21  13939.70  14200.00  13324.00       1464  20233135.70          722
# 2016-04-21   2018.95   2029.10   1956.20      28967  57987253.05         3264
# 2016-04-21     26.40     26.80     25.80      91366   2388936.45          576

# %%
print(clf.score(X_test,Y_test),"accuracy score")
# Out:
# 0.9998079821947051 accuracy score

# %%
predict=clf.predict(X_test)
test["predict"]=predict

# %%
import matplotlib.pyplot as plt
train.index=train.Date
test.index=test.Date
train["CLOSE"].plot()
test["CLOSE"].plot()
test["predict"].plot()
plt.legend(loc="best")
plt.show()

# %%
data=pd.read_csv("intern.csv")
lis=[]
for index,rows in data.iterrows():
    if rows[0]=="20MICRONS":
        lis.append(list(rows))
stocks=pd.DataFrame(lis,columns=data.columns)
stocks.to_csv("20micronS.csv",sep=",")
dataset=pd.read_csv("20micronS.csv")
X_test=dataset
Y_test=dataset
Y_test=Y_test.iloc[:,[6,11]]
X_test=X_test.iloc[:,[3,4,5,9,10,11,12]]
for i in range(X_test.shape[0]):
    if X_test.TIMESTAMP[i][3]=="7":
        num=0
    else:
        num=i
        print(X_test.TIMESTAMP[i][3])
        break
for i in range(num,X_test.shape[0]):
    if X_test.TIMESTAMP[i][3]=="6":
        num1=i
print(num,num1)
train=dataset
test=dataset
train=train[num:num1+1][:]
test.drop(test.index[range(num,num1+1)],inplace=True)
X_test.drop(X_test.index[range(num,num1+1)],inplace=True)
Y_test.drop(Y_test.index[range(num,num1+1)],inplace=True)
X_test["Date"]=pd.to_datetime(X_test.TIMESTAMP,format="%Y-%m-%d")
X_test.index=X_test["Date"]
Y_test["Date"]=pd.to_datetime(Y_test.TIMESTAMP,format="%Y-%m-%d")
Y_test.index=Y_test["Date"]
train["Date"]=pd.to_datetime(train.TIMESTAMP,format="%Y-%m-%d")
train.index=train["Date"]
test["Date"]=pd.to_datetime(test.TIMESTAMP,format="%Y-%m-%d")
test.index=test["Date"]
X_test=X_test.reset_index(drop=True)
Y_test=Y_test.reset_index(drop=True)
X_test=X_test.drop(columns="TIMESTAMP")
Y_test=Y_test.drop(columns="TIMESTAMP")
print(X_test)
X_test=X_test[0:X_test.shape[0]][:]
Y_test=Y_test[0:Y_test.shape[0]][:]
X_test=X_test.drop(columns="Date")
Y_test=Y_test.drop(columns="Date")
predict=clf.predict(X_test)
test["predict"]=predict
train.index=train.Date
test.index=test.Date
train["CLOSE"].plot()
test["CLOSE"].plot()
test["predict"].plot()
plt.legend(loc="best")
plt.show()
# Out:
#   File "<ipython-input-100-ded6a7116dc2>", line 6
#     if rows[0]==com
#                    ^
# SyntaxError: invalid syntax
